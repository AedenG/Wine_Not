# %%
import pandas as pd

red_df = pd.read_csv('binary_red_wine_df.csv')
white_df = pd.read_csv('binary_white_wine_df.csv')

# %%
joining_df = pd.DataFrame.append(red_df, white_df)
joining_df
# Out:
#       wine_type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0             1            7.4              0.70         0.00             1.9
# 1             1            7.8              0.88         0.00             2.6
# 2             1            7.8              0.76         0.04             2.3
# 3             1           11.2              0.28         0.56             1.9
# 4             1            7.4              0.70         0.00             1.9
# ...         ...            ...               ...          ...             ...
# 4893          0            6.2              0.21         0.29             1.6
# 4894          0            6.6              0.32         0.36             8.0
# 4895          0            6.5              0.24         0.19             1.2
# 4896          0            5.5              0.29         0.30             1.1
# 4897          0            6.0              0.21         0.38             0.8
#
# ...

# %%
joining_df.to_csv("combined_wine_df.csv", index=False)
