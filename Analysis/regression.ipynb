# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

red_wine = pd.read_csv('binary_red_wine_df.csv')
#red_wine = pd.read_csv('Resources/labelled_red_wine_df.csv')

# %%
red_wine.head()
# Out:
#    wine_type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0          1            7.4              0.70         0.00             1.9
# 1          1            7.8              0.88         0.00             2.6
# 2          1            7.8              0.76         0.04             2.3
# 3          1           11.2              0.28         0.56             1.9
# 4          1            7.4              0.70         0.00             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# ...

# %%
X = red_wine.drop(columns="wine_type")
y = red_wine['wine_type']

print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (1599, 12) (1599,)

# %%
red_wine.dropna()
# Out:
#       wine_type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0             1            7.4             0.700         0.00             1.9
# 1             1            7.8             0.880         0.00             2.6
# 2             1            7.8             0.760         0.04             2.3
# 3             1           11.2             0.280         0.56             1.9
# 4             1            7.4             0.700         0.00             1.9
# ...         ...            ...               ...          ...             ...
# 1594          1            6.2             0.600         0.08             2.0
# 1595          1            5.9             0.550         0.10             2.2
# 1596          1            6.3             0.510         0.13             2.3
# 1597          1            5.9             0.645         0.12             2.0
# 1598          1            6.0             0.310         0.47             3.6
#
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
#Create the model
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
   max_iter=200,
   random_state=1)

# %%
#Use the score() method on the model to show the R2 score
classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-7fba92884a42> in <module>
#       1 #Use the score() method on the model to show the R2 score
# ----> 2 classifier.fit(X_train, y_train)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1374             raise ValueError("This solver needs samples of at least 2 classes"
#    1375                              " in the data, but the data contains only one"
# -> 1376                              " class: %r" % classes_[0])
#    1377
#    1378         if len(self.classes_) == 2:
#
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 1

# %%
y_pred = classifier.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-20469ee708c2> in <module>
# ----> 1 y_pred = classifier.predict(X_test)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     307             Predicted class label per sample.
#     308         """
# --> 309         scores = self.decision_function(X)
#     310         if len(scores.shape) == 1:
#     311             indices = (scores > 0).astype(int)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_base.py in decision_function(self, X)
#     284         X = check_array(X, accept_sparse='csr')
#     285
# --> 286         n_features = self.coef_.shape[1]
#     287         if X.shape[1] != n_features:
#     288             raise ValueError("X has %d features per sample; expecting %d"
#
# ...

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-bf5c8bfa512c> in <module>
#       1 from sklearn.metrics import accuracy_score
# ----> 2 print(accuracy_score(y_test, y_pred))
#
# NameError: name 'y_pred' is not defined
